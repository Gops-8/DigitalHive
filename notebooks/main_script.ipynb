# %%
import os
import json
from datetime import datetime
from src.scrapper import WebScraper
from src.data_processer import DataProcessor
from src.content_analyzer import ContentAnalyzer

# %%
def setup_directories():
    """Create necessary directories if they don't exist"""
    dirs = ['output', 'output/scraping', 'output/analysis']
    for dir in dirs:
        os.makedirs(dir, exist_ok=True)

# %%
setup_directories()
        
# Initialize components
web_scraper = WebScraper()
data_processor = DataProcessor()
content_analyzer = ContentAnalyzer()

# %%
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
scraping_output = f"output/scraping/scraped_data_{timestamp}.json"
analysis_output = f"output/analysis/analysis_results_{timestamp}.json"

# %%
print("\n1. Reading URLs from Excel...")
excel_path = "File54.xlsx"  # Adjust path as needed
urls = data_processor.read_excel_to_url(excel_path)
print(f"Found {len(urls)} URLs")
# Out:
# 1. Reading URLs from Excel...
# Found 90001 URLs

# %%
## sampling 
urls = urls[:100]

# %%
print("\n2. Starting web scraping...")
scraping_results = {}

for i, url in enumerate(urls, 1):
  try:
      print(f"\nProcessing [{i}/{len(urls)}]: {url}")
      
      # Clean URL
      clean_url = data_processor.clean_url(url)
      print(f"Cleaned URL: {clean_url}")
      
      # Scrape website
      scraped_data = web_scraper.scrape_website(clean_url)
      
      # Store result
      scraping_results[url] = {
          'status': 'success',
          'cleaned_url': clean_url,
          'data': scraped_data,
          'timestamp': datetime.now().isoformat()
      }
      print("✓ Scraping successful")
      
  except Exception as e:
      print(f"✗ Error: {str(e)}")
      scraping_results[url] = {
          'status': 'error',
          'error': str(e),
          'timestamp': datetime.now().isoformat()
      }
# Out:
# 2. Starting web scraping...
#
# Processing [1/100]: http://Sanjosebengalcats.com
# Cleaned URL: https://Sanjosebengalcats.com
# ✓ Scraping successful
#
# Processing [2/100]: peachmarketplace.com
# Cleaned URL: https://peachmarketplace.com
# ✓ Scraping successful
#
# Processing [3/100]: peachmcintyre.com
# Cleaned URL: https://peachmcintyre.com
# ✓ Scraping successful
#
# Processing [4/100]: peachmedical.com
# Cleaned URL: https://peachmedical.com
# ✓ Scraping successful
#
# Processing [5/100]: peachmeleggings.com
# Cleaned URL: https://peachmeleggings.com
# ✓ Scraping successful
#
# Processing [6/100]: peachmode.com
# Cleaned URL: https://peachmode.com
# ✓ Scraping successful
#
# Processing [7/100]: peachmodern.com
# Cleaned URL: https://peachmodern.com
# ✓ Scraping successful
#
# Processing [8/100]: peach-momo.com
# Cleaned URL: https://peach-momo.com
# ✓ Scraping successful
#
# Processing [9/100]: peachmountain.com
# Cleaned URL: https://peachmountain.com
# ✓ Scraping successful
#
# Processing [10/100]: peachmusic.com
# Cleaned URL: https://peachmusic.com
# ✗ Error: Error scraping https://peachmusic.com: HTTPSConnectionPool(host='peachmusic.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'peachmusic.com'. (_ssl.c:1007)")))
#
# Processing [11/100]: peachmyk.com
# Cleaned URL: https://peachmyk.com
# ✗ Error: Error scraping https://peachmyk.com: HTTPSConnectionPool(host='peachmyk.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate (_ssl.c:1007)')))
#
# Processing [12/100]: peachofmind.com
# Cleaned URL: https://peachofmind.com
# ✓ Scraping successful
#
# Processing [13/100]: peachonaleash.com
# Cleaned URL: https://peachonaleash.com
# ✓ Scraping successful
#
# Processing [14/100]: peachorchardapartments.com
# Cleaned URL: https://peachorchardapartments.com
# ✓ Scraping successful
#
# Processing [15/100]: peachpalettedesign.com
# Cleaned URL: https://peachpalettedesign.com
# ✓ Scraping successful
#
# Processing [16/100]: peachpaperdesign.com
# Cleaned URL: https://peachpaperdesign.com
# ✓ Scraping successful
#
# Processing [17/100]: peachpeonyfashion.com
# Cleaned URL: https://peachpeonyfashion.com
# ✗ Error: Error scraping https://peachpeonyfashion.com: HTTPSConnectionPool(host='peachpeonyfashion.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7faf9a731930>: Failed to resolve 'peachpeonyfashion.com' ([Errno -2] Name or service not known)"))
#
# Processing [18/100]: peachperfectskincare.com
# Cleaned URL: https://peachperfectskincare.com
# ✓ Scraping successful
#
# Processing [19/100]: peachpiepups.com
# Cleaned URL: https://peachpiepups.com
# ✓ Scraping successful
#
# Processing [20/100]: peachpitgym.com
# Cleaned URL: https://peachpitgym.com
# ✓ Scraping successful
#
# Processing [21/100]: peachpitmusic.com
# Cleaned URL: https://peachpitmusic.com
# ✓ Scraping successful
#
# Processing [22/100]: peachpitpotteryshop.com
# Cleaned URL: https://peachpitpotteryshop.com
# ✓ Scraping successful
#
# Processing [23/100]: peachprism.com
# Cleaned URL: https://peachprism.com
# ✓ Scraping successful
#
# Processing [24/100]: peach-pump.com
# Cleaned URL: https://peach-pump.com
# ✓ Scraping successful
#
# Processing [25/100]: peachpups.com
# Cleaned URL: https://peachpups.com
# ✓ Scraping successful
#
# Processing [26/100]: peachresindesigns.com
# Cleaned URL: https://peachresindesigns.com
# ✗ Error: Error scraping https://peachresindesigns.com: HTTPSConnectionPool(host='peachresindesigns.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7faf997883d0>: Failed to resolve 'peachresindesigns.com' ([Errno -2] Name or service not known)"))
#
# Processing [27/100]: peachresindesigns.com
# Cleaned URL: https://peachresindesigns.com
# ✗ Error: Error scraping https://peachresindesigns.com: HTTPSConnectionPool(host='peachresindesigns.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7faf98a1c5b0>: Failed to resolve 'peachresindesigns.com' ([Errno -2] Name or service not known)"))
#
# Processing [28/100]: peachridge.com
# Cleaned URL: https://peachridge.com
# ✓ Scraping successful
#
# Processing [29/100]: peachridgeglass.com
# Cleaned URL: https://peachridgeglass.com
# ✓ Scraping successful
#
# Processing [30/100]: peachridgeres.com
# Cleaned URL: https://peachridgeres.com
# ✓ Scraping successful
#
# Processing [31/100]: peachring.com
# Cleaned URL: https://peachring.com
# ✓ Scraping successful
#
# Processing [32/100]: peachruby.com
# Cleaned URL: https://peachruby.com
# ✓ Scraping successful
#
# Processing [33/100]: peachscore.com
# Cleaned URL: https://peachscore.com
# ✓ Scraping successful
#
# Processing [34/100]: peachshark.com
# Cleaned URL: https://peachshark.com
# ✗ Error: Error scraping https://peachshark.com: HTTPSConnectionPool(host='peachshark.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7faf9a9bd060>: Failed to resolve 'peachshark.com' ([Errno -2] Name or service not known)"))
#
# Processing [35/100]: peachsign.com
# Cleaned URL: https://peachsign.com
# ✓ Scraping successful
#
# Processing [36/100]: peachskinlaser.com
# Cleaned URL: https://peachskinlaser.com
# ✓ Scraping successful
#
# Processing [37/100]: peachstateautobrokers.com
# Cleaned URL: https://peachstateautobrokers.com
# ✗ Error: Error scraping https://peachstateautobrokers.com: HTTPSConnectionPool(host='peachstateautobrokers.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7faf9a9bc730>, 'Connection to peachstateautobrokers.com timed out. (connect timeout=10)'))
#
# Processing [38/100]: peachstatebasketball.com
# Cleaned URL: https://peachstatebasketball.com
# ✓ Scraping successful
#
# Processing [39/100]: peachstatecandlesupply.com
# Cleaned URL: https://peachstatecandlesupply.com
# ✓ Scraping successful
#
# Processing [40/100]: peachstateco.com
# Cleaned URL: https://peachstateco.com
# ✓ Scraping successful
#
# Processing [41/100]: peachstatecollegesports.com
# Cleaned URL: https://peachstatecollegesports.com
# ✗ Error: Error scraping https://peachstatecollegesports.com: HTTPSConnectionPool(host='peachstatecollegesports.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate (_ssl.c:1007)')))
#
# Processing [42/100]: peachstateconsultants.com
# Cleaned URL: https://peachstateconsultants.com
# ✓ Scraping successful
#
# Processing [43/100]: peachstatecornhole.com
# Cleaned URL: https://peachstatecornhole.com
# ✓ Scraping successful
#
# Processing [44/100]: peachstategolf.com
# Cleaned URL: https://peachstategolf.com
# ✓ Scraping successful
#
# Processing [45/100]: peachstategym.com
# Cleaned URL: https://peachstategym.com
# ✓ Scraping successful
#
# Processing [46/100]: peachstatehangers.com
# Cleaned URL: https://peachstatehangers.com
# ✗ Error: Error scraping https://peachstatehangers.com: HTTPSConnectionPool(host='peachstatehangers.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7faf98ce7160>: Failed to resolve 'peachstatehangers.com' ([Errno -2] Name or service not known)"))
#
# Processing [47/100]: peachstatehobbies.com
# Cleaned URL: https://peachstatehobbies.com
# ✓ Scraping successful
#
# Processing [48/100]: peachstatelawyer.com
# Cleaned URL: https://peachstatelawyer.com
# ✓ Scraping successful
#
# Processing [49/100]: peachstatelawyer.com
# Cleaned URL: https://peachstatelawyer.com
# ✓ Scraping successful
#
# Processing [50/100]: peachstatelite.com
# Cleaned URL: https://peachstatelite.com
# ✓ Scraping successful
#
# Processing [51/100]: peachstatelumber.com
# Cleaned URL: https://peachstatelumber.com
# ✓ Scraping successful
#
# Processing [52/100]: peachstatepride.com
# Cleaned URL: https://peachstatepride.com
# ✓ Scraping successful
#
# Processing [53/100]: peachstateshirts.com
# Cleaned URL: https://peachstateshirts.com
# ✓ Scraping successful
#
# Processing [54/100]: peachstatesports.com
# Cleaned URL: https://peachstatesports.com
# ✓ Scraping successful
#
# Processing [55/100]: peachstreetdistillers.com
# Cleaned URL: https://peachstreetdistillers.com
# ✓ Scraping successful
#
# Processing [56/100]: peachsugaring.com
# Cleaned URL: https://peachsugaring.com
# ✗ Error: Error scraping https://peachsugaring.com: HTTPSConnectionPool(host='peachsugaring.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7faf9abc8d00>: Failed to resolve 'peachsugaring.com' ([Errno -2] Name or service not known)"))
#
# Processing [57/100]: peachswimwearusa.com
# Cleaned URL: https://peachswimwearusa.com
# ✗ Error: Error scraping https://peachswimwearusa.com: HTTPSConnectionPool(host='peachswimwearusa.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7faf998577f0>: Failed to resolve 'peachswimwearusa.com' ([Errno -2] Name or service not known)"))
#
# Processing [58/100]: peachtahiti.com
# Cleaned URL: https://peachtahiti.com
# ✓ Scraping successful
#
# Processing [59/100]: peachtao.com
# Cleaned URL: https://peachtao.com
# ✓ Scraping successful
#
# Processing [60/100]: peachtheband.com
# Cleaned URL: https://peachtheband.com
# ✓ Scraping successful
#
# Processing [61/100]: peachtree50.com
# Cleaned URL: https://peachtree50.com
# ✓ Scraping successful
#
# Processing [62/100]: peachtreeacademy.com
# Cleaned URL: https://peachtreeacademy.com
# ✓ Scraping successful
#
# Processing [63/100]: peachtree-accounting.com
# Cleaned URL: https://peachtree-accounting.com
# ✗ Error: Error scraping https://peachtree-accounting.com: HTTPSConnectionPool(host='peachtree-accounting.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7faf997885e0>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# Processing [64/100]: peachtreeallergyclinic.com
# Cleaned URL: https://peachtreeallergyclinic.com
# ✓ Scraping successful
#
# Processing [65/100]: peachtreebariatrics.com
# Cleaned URL: https://peachtreebariatrics.com
# ✓ Scraping successful
#
# Processing [66/100]: peachtreebaseball.com
# Cleaned URL: https://peachtreebaseball.com
# ✓ Scraping successful
#
# Processing [67/100]: peachtreebenefitgroup.com
# Cleaned URL: https://peachtreebenefitgroup.com
# ✓ Scraping successful
#
# Processing [68/100]: peachtreebikes.com
# Cleaned URL: https://peachtreebikes.com
# ✓ Scraping successful
#
# Processing [69/100]: peachtreeblinds.com
# Cleaned URL: https://peachtreeblinds.com
# ✓ Scraping successful
#
# Processing [70/100]: peachtreebooks.com
# Cleaned URL: https://peachtreebooks.com
# ✓ Scraping successful
#
# Processing [71/100]: peachtreeboutiquestore.com
# Cleaned URL: https://peachtreeboutiquestore.com
# ✓ Scraping successful
#
# Processing [72/100]: peachtreechurch.com
# Cleaned URL: https://peachtreechurch.com
# ✓ Scraping successful
#
# Processing [73/100]: peachtreecitybraces.com
# Cleaned URL: https://peachtreecitybraces.com
# ✓ Scraping successful
#
# Processing [74/100]: peachtreecitydentalgroup.com
# Cleaned URL: https://peachtreecitydentalgroup.com
# ✓ Scraping successful
#
# Processing [75/100]: peachtreecitymarket.com
# Cleaned URL: https://peachtreecitymarket.com
# ✓ Scraping successful
#
# Processing [76/100]: peachtreecitysmallenginerepair.com
# Cleaned URL: https://peachtreecitysmallenginerepair.com
# ✓ Scraping successful
#
# Processing [77/100]: peachtreecitywokexpress.com
# Cleaned URL: https://peachtreecitywokexpress.com
# ✓ Scraping successful
#
# Processing [78/100]: peachtreeclub.com
# Cleaned URL: https://peachtreeclub.com
# ✓ Scraping successful
#
# Processing [79/100]: peachtreecomedyfestival.com
# Cleaned URL: https://peachtreecomedyfestival.com
# ✓ Scraping successful
#
# Processing [80/100]: peachtreecornersexecutivesuites.com
# Cleaned URL: https://peachtreecornersexecutivesuites.com
# ✓ Scraping successful
#
# Processing [81/100]: peachtreecpr.com
# Cleaned URL: https://peachtreecpr.com
# ✓ Scraping successful
#
# Processing [82/100]: peachtreecre.com
# Cleaned URL: https://peachtreecre.com
# ✓ Scraping successful
#
# Processing [83/100]: peachtreecrossings.com
# Cleaned URL: https://peachtreecrossings.com
# ✗ Error: Error scraping https://peachtreecrossings.com: HTTPSConnectionPool(host='peachtreecrossings.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7faf98ce6b90>: Failed to resolve 'peachtreecrossings.com' ([Errno -2] Name or service not known)"))
#
# Processing [84/100]: peachtreedermatology.com
# Cleaned URL: https://peachtreedermatology.com
# ✓ Scraping successful
#
# Processing [85/100]: peachtreedesigns.com
# Cleaned URL: https://peachtreedesigns.com
# ✓ Scraping successful
#
# Processing [86/100]: peachtreedesigns.com
# Cleaned URL: https://peachtreedesigns.com
# ✓ Scraping successful
#
# Processing [87/100]: peachtreeestatescatawba.com
# Cleaned URL: https://peachtreeestatescatawba.com
# ✓ Scraping successful
#
# Processing [88/100]: peachtreeflowers.com
# Cleaned URL: https://peachtreeflowers.com
# ✓ Scraping successful
#
# Processing [89/100]: peachtreegym.com
# Cleaned URL: https://peachtreegym.com
# ✓ Scraping successful
#
# Processing [90/100]: peachtreegymnastics.com
# Cleaned URL: https://peachtreegymnastics.com
# ✗ Error: Error scraping https://peachtreegymnastics.com: HTTPSConnectionPool(host='peachtreegymnastics.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'peachtreegymnastics.com'. (_ssl.c:1007)")))
#
# Processing [91/100]: peachtreehearing.com
# Cleaned URL: https://peachtreehearing.com
# ✓ Scraping successful
#
# Processing [92/100]: peachtreehoops.com
# Cleaned URL: https://peachtreehoops.com
# ✓ Scraping successful
#
# Processing [93/100]: peachtreehotelgroup.com
# Cleaned URL: https://peachtreehotelgroup.com
# ✓ Scraping successful
#
# Processing [94/100]: peachtreeinvitational.com
# Cleaned URL: https://peachtreeinvitational.com
# ✓ Scraping successful
#
# Processing [95/100]: peachtreekidney.com
# Cleaned URL: https://peachtreekidney.com
# ✓ Scraping successful
#
# Processing [96/100]: peachtreekidsnantucket.com
# Cleaned URL: https://peachtreekidsnantucket.com
# ✓ Scraping successful
#
# Processing [97/100]: peachtreelanehoa.com
# Cleaned URL: https://peachtreelanehoa.com
# ✓ Scraping successful
#
# Processing [98/100]: peachtreelifeinsurance.com
# Cleaned URL: https://peachtreelifeinsurance.com
# ✓ Scraping successful
#
# Processing [99/100]: peachtreelighting.com
# Cleaned URL: https://peachtreelighting.com
# ✓ Scraping successful
#
# Processing [100/100]: peachtreemedicalcenter.com
# Cleaned URL: https://peachtreemedicalcenter.com
# ✓ Scraping successful

# %%
print("\nSaving scraping results...")
with open(scraping_output, 'w', encoding='utf-8') as f:
    json.dump(scraping_results, f, indent=2, ensure_ascii=False)
# Out:
# Saving scraping results...

# %%
print("\n3. Starting content analysis...")
analysis_results = content_analyzer.process_scraped_data(
    scraping_output,
    analysis_output
)
# Out:
# 3. Starting content analysis...
#
# Processing [1/97]: http://Sanjosebengalcats.com
# ✓ Analysis successful
#
# Processing [2/97]: peachmarketplace.com
# ✓ Analysis successful
#
# Processing [3/97]: peachmcintyre.com
# ✓ Analysis successful
#
# Processing [4/97]: peachmedical.com
# ✓ Analysis successful
#
# Processing [5/97]: peachmeleggings.com
# ✓ Analysis successful
#
# Processing [6/97]: peachmode.com
# ✓ Analysis successful
#
# Processing [7/97]: peachmodern.com
# ✓ Analysis successful
#
# Processing [8/97]: peach-momo.com
# ✓ Analysis successful
#
# Processing [9/97]: peachmountain.com
# ✓ Analysis successful
#
# Processing [10/97]: peachmusic.com
# ✗ Skipped - No valid content
#
# Processing [11/97]: peachmyk.com
# ✗ Skipped - No valid content
#
# Processing [12/97]: peachofmind.com
# ✓ Analysis successful
#
# Processing [13/97]: peachonaleash.com
# ✓ Analysis successful
#
# Processing [14/97]: peachorchardapartments.com
# ✓ Analysis successful
#
# Processing [15/97]: peachpalettedesign.com
# ✓ Analysis successful
#
# Processing [16/97]: peachpaperdesign.com
# ✓ Analysis successful
#
# Processing [17/97]: peachpeonyfashion.com
# ✗ Skipped - No valid content
#
# Processing [18/97]: peachperfectskincare.com
# ✓ Analysis successful
#
# Processing [19/97]: peachpiepups.com
# ✓ Analysis successful
#
# Processing [20/97]: peachpitgym.com
# ✓ Analysis successful
#
# Processing [21/97]: peachpitmusic.com
# ✓ Analysis successful
#
# Processing [22/97]: peachpitpotteryshop.com
# ✓ Analysis successful
#
# Processing [23/97]: peachprism.com
# ✓ Analysis successful
#
# Processing [24/97]: peach-pump.com
# ✓ Analysis successful
#
# Processing [25/97]: peachpups.com
# ✓ Analysis successful
#
# Processing [26/97]: peachresindesigns.com
# ✗ Skipped - No valid content
#
# Processing [27/97]: peachridge.com
# ✓ Analysis successful
#
# Processing [28/97]: peachridgeglass.com
# ✓ Analysis successful
#
# Processing [29/97]: peachridgeres.com
# ✓ Analysis successful
#
# Processing [30/97]: peachring.com
# ✓ Analysis successful
#
# Processing [31/97]: peachruby.com
# ✓ Analysis successful
#
# Processing [32/97]: peachscore.com
# ✓ Analysis successful
#
# Processing [33/97]: peachshark.com
# ✗ Skipped - No valid content
#
# Processing [34/97]: peachsign.com
# ✓ Analysis successful
#
# Processing [35/97]: peachskinlaser.com
# ✓ Analysis successful
#
# Processing [36/97]: peachstateautobrokers.com
# ✗ Skipped - No valid content
#
# Processing [37/97]: peachstatebasketball.com
# ✓ Analysis successful
#
# Processing [38/97]: peachstatecandlesupply.com
# ✓ Analysis successful
#
# Processing [39/97]: peachstateco.com
# ✓ Analysis successful
#
# Processing [40/97]: peachstatecollegesports.com
# ✗ Skipped - No valid content
#
# Processing [41/97]: peachstateconsultants.com
# ✓ Analysis successful
#
# Processing [42/97]: peachstatecornhole.com
# ✓ Analysis successful
#
# Processing [43/97]: peachstategolf.com
# ✓ Analysis successful
#
# Processing [44/97]: peachstategym.com
# ✓ Analysis successful
#
# Processing [45/97]: peachstatehangers.com
# ✗ Skipped - No valid content
#
# Processing [46/97]: peachstatehobbies.com
# ✓ Analysis successful
#
# Processing [47/97]: peachstatelawyer.com
# ✓ Analysis successful
#
# Processing [48/97]: peachstatelite.com
# ✓ Analysis successful
#
# Processing [49/97]: peachstatelumber.com
# ✓ Analysis successful
#
# Processing [50/97]: peachstatepride.com
# ✓ Analysis successful
#
# Processing [51/97]: peachstateshirts.com
# ✓ Analysis successful
#
# Processing [52/97]: peachstatesports.com
# ✓ Analysis successful
#
# Processing [53/97]: peachstreetdistillers.com
# ✓ Analysis successful
#
# Processing [54/97]: peachsugaring.com
# ✗ Skipped - No valid content
#
# Processing [55/97]: peachswimwearusa.com
# ✗ Skipped - No valid content
#
# Processing [56/97]: peachtahiti.com
# ✓ Analysis successful
#
# Processing [57/97]: peachtao.com
# ✓ Analysis successful
#
# Processing [58/97]: peachtheband.com
# ✓ Analysis successful
#
# Processing [59/97]: peachtree50.com
# ✓ Analysis successful
#
# Processing [60/97]: peachtreeacademy.com
# ✓ Analysis successful
#
# Processing [61/97]: peachtree-accounting.com
# ✗ Skipped - No valid content
#
# Processing [62/97]: peachtreeallergyclinic.com
# ✓ Analysis successful
#
# Processing [63/97]: peachtreebariatrics.com
# ✓ Analysis successful
#
# Processing [64/97]: peachtreebaseball.com
# ✓ Analysis successful
#
# Processing [65/97]: peachtreebenefitgroup.com
# ✓ Analysis successful
#
# Processing [66/97]: peachtreebikes.com
# ✓ Analysis successful
#
# Processing [67/97]: peachtreeblinds.com
# ✓ Analysis successful
#
# Processing [68/97]: peachtreebooks.com
# ✓ Analysis successful
#
# Processing [69/97]: peachtreeboutiquestore.com
# ✓ Analysis successful
#
# Processing [70/97]: peachtreechurch.com
# ✓ Analysis successful
#
# Processing [71/97]: peachtreecitybraces.com
# ✓ Analysis successful
#
# Processing [72/97]: peachtreecitydentalgroup.com
# ✓ Analysis successful
#
# Processing [73/97]: peachtreecitymarket.com
# ✓ Analysis successful
#
# Processing [74/97]: peachtreecitysmallenginerepair.com
# ✓ Analysis successful
#
# Processing [75/97]: peachtreecitywokexpress.com
# ✓ Analysis successful
#
# Processing [76/97]: peachtreeclub.com
# ✓ Analysis successful
#
# Processing [77/97]: peachtreecomedyfestival.com
# ✓ Analysis successful
#
# Processing [78/97]: peachtreecornersexecutivesuites.com
# ✓ Analysis successful
#
# Processing [79/97]: peachtreecpr.com
# ✓ Analysis successful
#
# Processing [80/97]: peachtreecre.com
# ✓ Analysis successful
#
# Processing [81/97]: peachtreecrossings.com
# ✗ Skipped - No valid content
#
# Processing [82/97]: peachtreedermatology.com
# ✓ Analysis successful
#
# Processing [83/97]: peachtreedesigns.com
# ✓ Analysis successful
#
# Processing [84/97]: peachtreeestatescatawba.com
# ✓ Analysis successful
#
# Processing [85/97]: peachtreeflowers.com
# ✓ Analysis successful
#
# Processing [86/97]: peachtreegym.com
# ✓ Analysis successful
#
# Processing [87/97]: peachtreegymnastics.com
# ✗ Skipped - No valid content
#
# Processing [88/97]: peachtreehearing.com
# ✓ Analysis successful
#
# Processing [89/97]: peachtreehoops.com
# ✓ Analysis successful
#
# Processing [90/97]: peachtreehotelgroup.com
# ✓ Analysis successful
#
# Processing [91/97]: peachtreeinvitational.com
# ✓ Analysis successful
#
# Processing [92/97]: peachtreekidney.com
# ✓ Analysis successful
#
# Processing [93/97]: peachtreekidsnantucket.com
# ✓ Analysis successful
#
# Processing [94/97]: peachtreelanehoa.com
# ✓ Analysis successful
#
# Processing [95/97]: peachtreelifeinsurance.com
# ✓ Analysis successful
#
# Processing [96/97]: peachtreelighting.com
# ✓ Analysis successful
#
# Processing [97/97]: peachtreemedicalcenter.com
# ✓ Analysis successful

# %%
successful_scrapes = len([r for r in scraping_results.values() if r['status'] == 'success'])
successful_analyses = len([r for r in analysis_results.values() if r['status'] == 'success'])

# %%
print("\n=== Final Summary ===")
print(f"Total URLs processed: {len(urls)}")
print("\nScraping Results:")
print(f"- Successful: {successful_scrapes}")
print(f"- Failed: {len(urls) - successful_scrapes}")
print(f"- Output file: {scraping_output}")

print("\nAnalysis Results:")
print(f"- Successful: {successful_analyses}")
print(f"- Failed/Skipped: {len(urls) - successful_analyses}")
print(f"- Output file: {analysis_output}")
# Out:
# === Final Summary ===
# Total URLs processed: 100
#
# Scraping Results:
# - Successful: 84
# - Failed: 16
# - Output file: output/scraping/scraped_data_20241224_154243.json
#
# Analysis Results:
# - Successful: 84
# - Failed/Skipped: 16
# - Output file: output/analysis/analysis_results_20241224_154243.json

# %%
for url,data in analysis_results.items():
  print(url , data)
# Out:
# http://Sanjosebengalcats.com {'status': 'success', 'analysis': {'keywords': ['Bengal cats', 'San Jose Bengal Cats', 'Bengal kittens for sale', 'Bengal adults for sale', 'Are Bengal Cats smarter than other Cat Breeds?', 'Bengal kitten pricing'], 'business_name': 'San Jose Bengal Cats', 'products_services': 'Bengal kittens and Bengal cats for sale, Bengal breeding program, health checked by a licensed veterinarian, Pedigree Paperwork', 'target_audience': 'New York, Los Angeles, Miami, and beyond!', 'emails': ['rene@sanjosebengalcats.com'], 'phones': []}, 'timestamp': '2024-12-24T16:14:00.057634'}
# peachmarketplace.com {'status': 'success', 'analysis': {'keywords': ['leopard', 'pumpkin', ' Halloween', 'embroidery', 'accessories', 't-shirts', 'long sleeve', 'quality', 'reviews'], 'business_name': 'Peach Marketplace', 'products_services': 'Home accessories, holiday collection, embroidery, clearance, full catalog, reviews.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:14:01.612604'}
# peachmcintyre.com {'status': 'success', 'analysis': {'keywords': ['social media content creator', 'big bag big bank', 'home shop e-guide', 'book online more'], 'business_name': 'Peach McIntyre Inc.', 'products_services': 'Social Media Content Creator, Home Shop E-Guide, Book Online More', 'emails': ['Inc.813.797.1396support@peachmcintyre.com', 'support@peachmcintyre.com'], 'phones': ['']}, 'timestamp': '2024-12-24T16:14:03.021023'}
# peachmedical.com {'status': 'success', 'analysis': {'keywords': ['Pfizer', 'COVID-19', 'flu', 'home test', 'rapid test'], 'business_name': 'Peach Medical', 'products_services': 'Providing industry-leading fulfillment technology and product procurement expertise, simplifying B2B and e-commerce purchasing.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:14:04.486476'}
# peachmeleggings.com {'status': 'success', 'analysis': {'keywords': ['peachmeleggings', 'leggings', 'shorts', 'flare pants', 'sets'], 'business_name': 'Peach Me Leggings', 'products_services': "Women's leggings, shorts, flare pants, and sets made from high-quality materials for comfortable and stylish fashion.", 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:14:06.078729'}
# peachmode.com {'status': 'success', 'analysis': {'keywords': ['sarees', 'fabric', 'cotton', 'silk', 'chiffon', 'georgette', 'crepe', 'organza', 'bhagalpuri', 'banarasi', 'chanderi', 'patola'], 'business_name': 'Peachmode', 'products_services': 'Sarees, Fabric, Cotton, Silk, Chiffon, Georgette, Crepe, Organza, Bhagalpuri, Banarasi, Chanderi, Patola', 'emails': ['contact@peachmode.com'], 'phones': []}, 'timestamp': '2024-12-24T16:14:08.237915'}
# peachmodern.com {'status': 'success', 'analysis': {'keywords': ['furniture', 'art', 'collectibles', 'unique collection', 'peach modern'], 'business_name': 'Peach Modern', 'products_services': 'Furniture, art, and collectibles', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:14:09.341041'}
# peach-momo.com {'status': 'success', 'analysis': {'articles': [{'title': 'Best Now', 'description': 'Get the latest deals and recommendations on home goods, electronics, and more.', 'images': [{'image': 'https://media.io/v1/768x5760/best-now.png', 'alt': 'Best Now'}, {'image': 'https://media.io/v1/768x5760/deals.png', 'alt': 'Deals'}, {'image': 'https://media.io/v1/768x5760/recommendations.png', 'alt': 'Recommendations'}], 'keywords': ['home goods', 'electronics', 'deals', 'recommendations'], 'categories': [{'name': 'Home Goods', 'description': 'Find the latest deals and recommendations on home goods, including furniture, kitchen appliances, and more.'}, {'name': 'Electronics', 'description': 'Stay up to date with the latest deals and recommendations on electronics, including smartphones, laptops, and more.'}], 'brands': [{'name': 'Bed Bath & Beyond', 'image': 'https://media.io/v1/768x5760/bed-bath-beyond.png', 'description': 'Discover the latest deals and recommendations on home goods from Bed Bath & Beyond.'}, {'name': 'HelloFresh', 'image': 'https://media.io/v1/768x5760/hellofresh.png', 'description': 'Explore the latest deals and recommendations on meal kits from HelloFresh.'}]}], 'relatedArticles': [{'title': 'Best Now', 'description': 'Get the latest deals and recommendations on home goods, electronics, and more.', 'images': [{'image': 'https://media.io/v1/768x5760/best-now.png', 'alt': 'Best Now'}, {'image': 'https://media.io/v1/768x5760/deals.png', 'alt': 'Deals'}, {'image': 'https://media.io/v1/768x5760/recommendations.png', 'alt': 'Recommendations'}], 'keywords': ['home goods', 'electronics', 'deals', 'recommendations'], 'categories': [{'name': 'Home Goods', 'description': 'Find the latest deals and recommendations on home goods, including furniture, kitchen appliances, and more.'}, {'name': 'Electronics', 'description': 'Stay up to date with the latest deals and recommendations on electronics, including smartphones, laptops, and more.'}], 'brands': [{'name': 'Bed Bath & Beyond', 'image': 'https://media.io/v1/768x5760/bed-bath-beyond.png', 'description': 'Discover the latest deals and recommendations on home goods from Bed Bath & Beyond.'}, {'name': 'HelloFresh', 'image': 'https://media.io/v1/768x5760/hellofresh.png', 'description': 'Explore the latest deals and recommendations on meal kits from HelloFresh.'}]}, {'title': 'Best Deals Now', 'description': 'Get the latest deals and discounts on home goods, electronics, and more.', 'images': [{'image': 'https://media.io/v1/768x5760/deals.png', 'alt': 'Deals'}, {'image': 'https://media.io/v1/768x5760/discounts.png', 'alt': 'Discounts'}], 'keywords': ['deals', 'discounts', 'home goods', 'electronics'], 'categories': [{'name': 'Home Goods', 'description': 'Find the latest deals and recommendations on home goods, including furniture, kitchen appliances, and more.'}, {'name': 'Electronics', 'description': 'Stay up to date with the latest deals and recommendations on electronics, including smartphones, laptops, and more.'}], 'brands': [{'name': 'Bed Bath & Beyond', 'image': 'https://media.io/v1/768x5760/bed-bath-beyond.png', 'description': 'Discover the latest deals and recommendations on home goods from Bed Bath & Beyond.'}, {'name': 'HelloFresh', 'image': 'https://media.io/v1/768x5760/hellofresh.png', 'description': 'Explore the latest deals and recommendations on meal kits from HelloFresh.'}]}], 'relatedArticlesMetaData': {'title': 'Related Articles', 'description': 'Browse the latest deals and recommendations on home goods, electronics, and more.', 'keywords': ['deals', 'discounts', 'home goods', 'electronics'], 'images': [{'image': 'https://media.io/v1/768x5760/deals.png', 'alt': 'Deals'}, {'image': 'https://media.io/v1/768x5760/discounts.png', 'alt': 'Discounts'}], 'categories': [{'name': 'Home Goods', 'description': 'Find the latest deals and recommendations on home goods, including furniture, kitchen appliances, and more.'}, {'name': 'Electronics', 'description': 'Sta ...
# peachmountain.com {'status': 'success', 'analysis': {'keywords': ['tanks', 'fortifications', 'ships', 'planes', 'books', 'games', 'essays', 'travel'], 'business_name': 'Peachmountain.com', 'products_services': 'History, Photos of Tanks, Fortifications, Ships and Planes, Books, Games, Essays and Travel', 'emails': ['info@usaww1.com'], 'phones': []}, 'timestamp': '2024-12-24T16:14:34.800705'}
# peachmusic.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:14:34.800766'}
# peachmyk.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:14:34.800773'}
# peachofmind.com {'status': 'success', 'analysis': {'keywords': ['Peach of Mind', 'lifestyle blog', 'baby costumes', 'Halloween decorations', 'Winnie the Pooh', 'baby shower', 'roasted broccoli', 'summer clothing', 'dinnerware', 'palazzo pants'], 'business_name': 'Peach of Mind', 'products_services': 'Lifestyle blog with a focus on family, fashion, and home decor. Also offers baby costumes, Halloween decorations, and summer clothing recommendations.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:14:36.869447'}
# peachonaleash.com {'status': 'success', 'analysis': {'keywords': ['dog training', 'Atlanta', 'Peach on a Leash', 'board and train', 'in-home training', 'group classes', 'puppy training', 'manners and obedience', 'leash training', 'aggression training', 'therapy dog training'], 'business_name': 'Peach on a Leash Dog Training and Behavior Services', 'products_services': 'Dog training, board and train, in-home training, group classes, puppy training, manners and obedience, leash training, aggression training, therapy dog training', 'emails': ['info@peachonaleash.com'], 'phones': []}, 'timestamp': '2024-12-24T16:14:38.875578'}
# peachorchardapartments.com {'status': 'success', 'analysis': {'keywords': ['Peach Orchard Apartments', 'Augusta', 'GA', 'apartments', 'luxury living', 'affordable prices'], 'business_name': 'Peach Orchard Apartments', 'products_services': 'Luxury apartments for rent in Augusta, GA with affordable prices.', 'emails': ['peachorchard@gatewaymgt.com'], 'phones': []}, 'timestamp': '2024-12-24T16:14:40.335113'}
# peachpalettedesign.com {'status': 'success', 'analysis': {'keywords': ['store', 'unavailable', 'what happened', 'return to previous page'], 'business_name': 'Peach Palettes Design', 'products_services': '', 'target_audience': '', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:14:41.106360'}
# peachpaperdesign.com {'status': 'success', 'analysis': {'keywords': ['wedding invitation design', 'small business branding', 'graphic design', 'stationery'], 'business_name': 'Peach Paper & Design', 'products_services': 'Creating unique wedding stationery for the thoughtful couple AND helping creative bosses follow their dreams with modern branding.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:14:42.365370'}
# peachpeonyfashion.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:14:42.365434'}
# peachperfectskincare.com {'status': 'success', 'analysis': {'keywords': ['waxing', 'facials', 'spa body treatments', 'hair removal', 'Brazilian bikini wax'], 'business_name': 'Peach Perfect', 'products_services': 'full body waxing, eyebrow shaping, signature Brazilian bikini wax, custom facials, and rejuvenating body treatments.', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:14:43.965314'}
# peachpiepups.com {'status': 'success', 'analysis': {'keywords': ['Peach Pie Pups', 'gourmet dog treats', 'artisanal pet food'], 'business_name': 'Peach Pie Pops', 'products_services': 'handcrafted gourmet dog treats and artisanal pet food', 'target_audience': 'dog owners and pet lovers', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:14:44.907850'}
# peachpitgym.com {'status': 'success', 'analysis': {'keywords': ['gymnastics', 'cheerleading', 'dance', 'competitive teams', 'tumbling', 'trampoline'], 'business_name': 'The Peach Pit GymNAstics, LLC', 'products_services': 'Gymnastics, Cheerleading, Dance, Competitive Teams, Tumbling & Trampoline', 'emails': ['theprado@peachpitgym.com', 'manager@peachpitgym.com', 'dance@peachpitgym.com', 'ssi@peachpitgym.com'], 'phones': ['']}, 'timestamp': '2024-12-24T16:14:46.432113'}
# peachpitmusic.com {'status': 'success', 'analysis': {'keywords': ['Magpie', 'Every Little Thing', 'Did You Love Somebody', 'Peach Pit'], 'business_name': 'Peach Pit', 'products_services': "New album 'Magpie' Out Now! Listen + Download 'Every Little Thing' Listen + Download 'Did You Love Somebody' Listen + Download 'Magpie'", 'target_audience': 'United States, United Kingdom, Canada, Afghanistan, Albania, Algeria, American Samoa, Andorra, Angola, Anguilla, Antarctica, Antigua and Barbuda, Argentina, Armenia, Aruba, Australia, Austria, Azerbaijan, Bahamas, Bahrain, Bangladesh, Barbados, Belarus, Belgium, Belize, Benin, Bermuda, Bhutan, Bolivia, Bosnia and Herzegovina, Botswana, Bouvet Island, Brazil, British Indian Ocean Territory, Brunei Darussalam', 'postal_code': '12345', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:14:49.964894'}
# peachpitpotteryshop.com {'status': 'success', 'analysis': {'keywords': ['Peach Pit Pottery Shop', 'ceramics', 'gallery', 'handmade', 'artisanal'], 'business_name': 'Peach Pit Pottery Shop', 'products_services': 'Ceramics, gallery, handmade, artisanal', 'emails': ['info@peachpitpotteryshop.com'], 'phones': []}, 'timestamp': '2024-12-24T16:14:50.954973'}
# peachprism.com {'status': 'success', 'analysis': {'keywords': ['bedding', 'blanket', 'duvet covers', 'mattress', 'quilt'], 'business_name': 'Peach Prism', 'products_services': 'bedding, blankets, duvet covers, mattresses, quilts', 'emails': ['sales@peachprism.com'], 'phones': ['']}, 'timestamp': '2024-12-24T16:14:52.279658'}
# peach-pump.com {'status': 'success', 'analysis': {'keywords': ['gym clothing', 'yoga clothing', 'seamless leggings', 'leggings', 'black flare leggings', 'shaping effect', 'Peach Pump', 'sports bras', 'crop tops', 'sport sets'], 'business_name': 'Peach Pump', 'products_services': 'Gym clothing, yoga clothing, seamless leggings, leggings, black flare leggings, shaping effect. Sports bras, crop tops, sport sets.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:14:54.309482'}
# peachpups.com {'status': 'success', 'analysis': {'keywords': ['Peach Pups', 'dog accessories', 'collar', 'bandana', 'Christmas'], 'business_name': 'Peach Pups', 'products_services': 'dog accessories, collars, bandanas, Christmas', 'target_audience': 'dog owners and enthusiasts', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:14:55.592688'}
# peachresindesigns.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:14:55.592759'}
# peachridge.com {'status': 'success', 'analysis': {'keywords': ['Peach Ridge Orchard Supply', 'fruit and vegetable growers', 'landscape professionals', 'tree training', 'trellis supplies', 'tree ties', 'tree grafting', 'hand pruners', 'loppers', 'pole pruners', 'pneumatic pruners', 'chain saws', 'hydraulic pruners', 'quality tools', 'fast shipping', 'replacement parts', 'electric pruning systems', 'hydraulic pruning systems', 'pneumatic pruning systems'], 'business_name': 'Peach Ridge Orchard Supply', 'products_services': 'tree training, trellis supplies, tree ties, tree grafting, hand pruners, loppers, pole pruners, pneumatic pruners, chain saws, hydraulic pruners, quality tools, fast shipping, replacement parts, electric pruning systems, hydraulic pruning systems, pneumatic pruning systems', 'emails': ['sales@peachridge.com'], 'phones': ['']}, 'timestamp': '2024-12-24T16:14:58.982700'}
# peachridgeglass.com {'status': 'success', 'analysis': {'keywords': ['antique bottle', 'glass news', 'Federation of Historical Bottle Collectors', 'Bottles and Extras', 'early American antique bottles', 'Georgia sodas', 'figural bitters bottles', "Dr. Wonser's Indian Root Bitters", 'square bottle', 'lightly embossed', 'hexagonal Gothic peppersauce bottles', 'condiments for food'], 'business_name': 'Peachridge Glass', 'products_services': 'antique bottle and glass news, research, and collectibles', 'target_audience': 'collectors of early American antique bottles and glass, historical bottle collectors, enthusiasts of figural bitters bottles and hexagonal Gothic peppersauce bottles', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:01.713727'}
# peachridgeres.com {'status': 'success', 'analysis': {'keywords': ['independent oil', 'natural gas', 'acquisition', 'development', 'exploitation', 'exploration'], 'business_name': 'PeachRidge Energy Partners, LLC', 'products_services': 'oil and natural gas company', 'target_audience': 'communities where our employees live and work', 'emails': ['land@peachridgeres.com', 'ap@peachridgeres.com'], 'phones': []}, 'timestamp': '2024-12-24T16:15:03.026917'}
# peachring.com {'status': 'success', 'analysis': {'keywords': ['peach ring', 'wedding rings', 'engagement rings'], 'business_name': 'Peach Ring', 'products_services': 'handcrafted wedding and engagement rings', 'target_audience': 'couples and individuals looking for unique, high-quality rings', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:03.880227'}
# peachruby.com {'status': 'success', 'analysis': {'keywords': ['beauty', 'bath', 'body', 'care', 'fragrance', 'hair', 'massage', 'oils', 'skincare'], 'business_name': 'Peach Ruby', 'products_services': 'Soap, bath accessories, body & massage oils, hair care, fragrance, skincare.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:05.373696'}
# peachscore.com {'status': 'success', 'analysis': {'keywords': ['peachscore', 'peachscore.com'], 'business_name': 'Peach Score', 'products_services': 'online privacy and security assessment platform', 'target_audience': 'individuals and businesses', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:06.436361'}
# peachshark.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:15:06.436425'}
# peachsign.com {'status': 'success', 'analysis': {'keywords': ['responsive design', 'graphic design', 'web development'], 'business_name': 'Peach Sign', 'products_services': 'Graphic design, web development, and digital marketing services for small businesses and startups.', 'target_audience': 'Small businesses and startups', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:07.330928'}
# peachskinlaser.com {'status': 'success', 'analysis': {'keywords': ['Botox', 'wrinkle injections', 'laser hair removal', 'lip shape and enhancement', 'microneedling and facials'], 'business_name': 'Peach Skin & Laser', 'products_services': 'Offering Botox wrinkle injections, laser hair removal, lip shape and enhancement, and microneedling and facials. Book online today!', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:09.010242'}
# peachstateautobrokers.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:15:09.010303'}
# peachstatebasketball.com {'status': 'success', 'analysis': {'keywords': ['grassroots basketball', 'basketball recruiting', 'basketball tournaments', 'basketball training', 'Brandon Clay Scouting Report', 'Brandon Clay Showcases'], 'business_name': 'Peach State Basketball', 'products_services': 'Grassroots basketball events and showcases for high school athletes, recruiting services, training programs, and merchandise sales.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:10.637051'}
# peachstatecandlesupply.com {'status': 'success', 'analysis': {'keywords': ['candle making supplies', 'fragrance oils', 'wholesale'], 'business_name': 'Peach State Candle Supply', 'products_services': 'Candle making supplies, fragrance oils, and wholesale products.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:11.876332'}
# peachstateco.com {'status': 'success', 'analysis': {'keywords': ['civil construction', 'road construction', 'concrete installation', 'civil site development'], 'business_name': 'Peach State Construction Company', 'products_services': 'Provides civil construction services for multiple facets of industry, including road construction, concrete installation, and civil site development.', 'emails': ['770-788-6363info@peachstateco.com', 'info@peachstateco.com'], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:13.051424'}
# peachstatecollegesports.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:15:13.051482'}
# peachstateconsultants.com {'status': 'success', 'analysis': {'keywords': ['private home care', 'consulting services', 'HFRD regulations', 'licensure', 'compliance'], 'business_name': 'Peach State Private Home Care Consultants, LLC', 'products_services': 'professional consulting services to private home care providers throughout the State of Georgia', 'target_audience': 'potential and current agencies with timely, exceptional service to achieve success through compliance and quality care!', 'emails': ['peachstateconsultants@yahoo.com'], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:14.681148'}
# peachstatecornhole.com {'status': 'success', 'analysis': {'keywords': ['cornhole', 'leagues', 'tournaments', 'sponsorship', 'Georgia'], 'business_name': 'Peach State Cornhole', 'products_services': 'Adult social and competitive cornhole leagues, tournament hosting, event planning, and cornhole board rentals in Georgia.', 'emails': ['Info@peachstatecornhole.com'], 'phones': []}, 'timestamp': '2024-12-24T16:15:15.954249'}
# peachstategolf.com {'status': 'success', 'analysis': {'keywords': ['golf', 'equipment', 'apparel', 'accessories', 'fittings', 'expert advice'], 'business_name': 'Peach State Golf', 'products_services': 'top-quality equipment, apparel, and accessories to elevate your game to new heights', 'emails': ['ClosedContact+1-678-272-0644peachstategolfstore@gmail.com', 'peachstategolfstore@gmail.com', 'ClosedContact+1-678-272-0644peachstategolfstore@gmail.comPeach', 'Contact+1-678-272-0644peachstategolfstore@gmail.com'], 'phones': ['+1-']}, 'timestamp': '2024-12-24T16:15:17.274879'}
# peachstategym.com {'status': 'success', 'analysis': {'keywords': ['gymnastics', 'peach state gymnastics', 'recreational gymnastics', 'competition gymnastics', 'boys gymnastics', 'tumbling', 'private lessons'], 'business_name': 'Peach State Gymnastics', 'products_services': 'Recreational gymnastics, Competition gymnastics, Boys gymnastics, Tumbling, Private lessons', 'emails': ['info@peachstategym.com'], 'phones': []}, 'timestamp': '2024-12-24T16:15:19.153048'}
# peachstatehangers.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:15:19.153105'}
# peachstatehobbies.com {'status': 'success', 'analysis': {'keywords': ['buggy wheels', 'truggy wheels', 'racing', 'RC'], 'business_name': 'Peach State Hobbies', 'products_services': 'Buggy Wheels, Truggy Wheels, Racing RC', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:20.356031'}
# peachstatelawyer.com {'status': 'success', 'analysis': {'keywords': ['DUI defense', 'criminal defense', 'law firm', 'Atlanta', 'Georgia'], 'business_name': 'W. Scott Smith, P.C.', 'products_services': 'criminal defense law firm', 'target_audience': 'clients in metro Atlanta and Georgia', 'emails': ['FacebookTwitterLinkedInYoutubehelp@peachstatelawyer.com', 'help@peachstatelawyer.com'], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:21.622971'}
# peachstatelite.com {'status': 'success', 'analysis': {'keywords': ['Peach State Lite', 'Georgia', 'beer', 'lager', 'tailgates', 'UGA Football', 'hikes', 'beach', 'Braves game', 'golfing', 'concert', 'fishing'], 'business_name': 'Peach State Lite', 'products_services': 'beer, lager', 'target_audience': 'Georgia residents and beyond', 'emails': ['jake@peachstatelite.com'], 'phones': []}, 'timestamp': '2024-12-24T16:15:23.219519'}
# peachstatelumber.com {'status': 'success', 'analysis': {'keywords': ['lumber', 'hardwood', 'softwood', 'exotic wood', 'retail area', 'product sales', 'delivery available'], 'business_name': 'Peach State Lumber Products Inc.', 'products_services': 'lumber, hardwood products, softwoods and exotic woods. Delivery available.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:24.594053'}
# peachstatepride.com {'status': 'success', 'analysis': {'keywords': ['Peach State Pride', 'Georgia Bulldogs', 'UGA', 'Georgia Tech', 'Collegiate apparel', 'short sleeve tees', 'long sleeve tees', 'polo shirts', 'hat'], 'business_name': 'Peach State Pride', 'products_services': 'Collegiate apparel, short sleeve tees, long sleeve tees, polo shirts, hats', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:26.457502'}
# peachstateshirts.com {'status': 'success', 'analysis': {'keywords': ['Peach State Shirts', 'country club', 'Greenville Patriots', 'music radio', 'cars & trucks', "90's hip-hop", 'fashion-cool vintage dirtbike', 'Christmas', 'Smith-Fletcher Funeral Home', 'hats', 'wall art'], 'business_name': 'Peach State Shirts', 'products_services': 't-shirts, hoodies, sweatpants, mugs, posters, stickers, and other fun stuff.', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:28.601929'}
# peachstatesports.com {'status': 'success', 'analysis': {'keywords': ['sports cards', 'hobby supplies', 'wholesale accounts'], 'business_name': 'Peachstate Hobby', 'products_services': 'Sports cards, Memorabilia, and supplies', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:29.566590'}
# peachstreetdistillers.com {'status': 'success', 'analysis': {'keywords': ['Peach Street Distillers', 'bourbon whiskey', 'gins', 'vodka', "d'agave brandy", 'fruit and grape brandies', 'grappa', 'eau de vie', 'amaro'], 'business_name': 'Peach Street Distillers', 'products_services': "bourbon whiskey, gin, vodka, d'agave brandy, fruit & grape brandies, grappa, eau de vie, amaro", 'target_audience': 'craft spirits enthusiasts, bartenders, restaurateurs, mixologists', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:31.886691'}
# peachsugaring.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:15:31.886752'}
# peachswimwearusa.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:15:31.886758'}
# peachtahiti.com {'status': 'success', 'analysis': {'keywords': ['beauty of Joseon', 'COSRX', 'missha', 'K-beauty', 'skincare', 'makeup', 'hair care', 'face masks', 'vegan', 'hyaluronic acid', 'vitamin C'], 'business_name': 'Peach Tahiti', 'products_services': 'Skincare, makeup, hair care, face masks, and vegan products.', 'target_audience': 'Women aged 25-45 interested in K-beauty and skincare.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:34.164372'}
# peachtao.com {'status': 'success', 'analysis': {'keywords': ['murals', 'illustrations', 'storyboards', 'sketchbook'], 'business_name': 'Peach Tao', 'products_services': 'Murals, illustrations, storyboards, and sketchbook.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:35.398076'}
# peachtheband.com {'status': 'success', 'analysis': {'keywords': ['noise rock', 'Bristol', 'UK', 'Desert Rock', 'Punk', 'Grunge', 'angry', 'honest'], 'business_name': 'PEACH', 'products_services': 'four-piece noise rock band', 'emails': ['peachbanduk@gmail.com'], 'phones': []}, 'timestamp': '2024-12-24T16:15:36.308255'}
# peachtree50.com {'status': 'success', 'analysis': {'keywords': ['Peachtree Road Race', 'Atlanta Track Club', 'Jeff Galloway', 'Dr. Tim Singleton'], 'business_name': 'Atlanta Track Club', 'products_services': 'organizing and hosting the AJC Peachtree Road Race, providing membership benefits and opportunities for runners and fitness enthusiasts', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:37.721481'}
# peachtreeacademy.com {'status': 'success', 'analysis': {'keywords': ['Peachtree Academy', 'private school', 'education', 'academic programs', 'athletics', ' extracurricular activities'], 'business_name': 'Peachtree Academy', 'products_services': 'Private school offering academic programs and athletics for students in grades K-12. Includes Lower School, Middle School, and High School programs, as well as extracurricular activities such as sports teams, fine arts, and clubs.', 'target_audience': 'Parents of children in grades K-12, as well as students interested in attending Peachtree Academy.', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:39.768318'}
# peachtree-accounting.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:15:39.768377'}
# peachtreeallergyclinic.com {'status': 'success', 'analysis': {'keywords': ['Peachtree Allergy & Asthma', 'offices & clinics for allergies and asthma'], 'business_name': 'Peachtree Allergy & Asthma', 'products_services': 'offices & clinics for allergies and asthma', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:41.069378'}
# peachtreebariatrics.com {'status': 'success', 'analysis': {'keywords': ['gastric bypass', 'gastric sleeve', 'Orbera', 'intragastric balloon', 'laparoscopic surgery', 'weight loss'], 'business_name': 'Peachtree Surgical & Bariatrics', 'products_services': 'Laparoscopic gastric bypass, gastric sleeve, Orbera, intragastric balloon, and weight loss services.', 'target_audience': 'Individuals seeking weight loss solutions through bariatric surgery and non-invasive procedures.', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:43.353028'}
# peachtreebaseball.com {'status': 'success', 'analysis': {'keywords': ['Peachtree Baseball and Softball', 'T-Ball', 'Baseball', 'Softball', 'Coaching', 'Sponsorship', 'Volunteer', 'Registration', 'Play Peachtree!', 'Bad Weather'], 'business_name': 'Peachtree Baseball and Softball League', 'products_services': 'Baseball and Softball leagues for children ages 4-12, including T-Ball, Baseball, and Softball. Also offer coaching, sponsorship, volunteer opportunities, and registration services.', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:45.343139'}
# peachtreebenefitgroup.com {'status': 'success', 'analysis': {'keywords': ['Acrisure', 'insurance', 'mortgages', 'business insurance', 'large business solutions', 'employee benefit services', 'cybersecurity & managed IT'], 'business_name': 'Peachtree Benefit Group', 'products_services': 'Personal Insurance, Mortgages, Business Insurance, Large Business Solutions, Employee Benefit Services, Cybersecurity & Managed IT', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:46.975914'}
# peachtreebikes.com {'status': 'success', 'analysis': {'keywords': ['bike', 'sale', 'electric bikes', 'Specialized'], 'business_name': 'Peachtree Bikes', 'products_services': 'Bikes, Electric Equipment, Apparel, About Rides Sale', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:48.199059'}
# peachtreeblinds.com {'status': 'success', 'analysis': {'keywords': ['Peachtree Blinds', 'Atlanta', 'window treatments', 'shutters', 'blinds', 'plantation shutters', 'wooden blinds', 'faux blinds', 'custom draperies', 'outdoor shades', 'retractable screen doors', 'motorized screens'], 'business_name': 'Peachtree Blinds of Atlanta', 'products_services': 'window treatments, shutters, blinds, plantation shutters, wooden blinds, faux blinds, custom draperies, outdoor shades, retractable screen doors, motorized screens', 'target_audience': 'Atlanta, Decatur, Alpharetta, Roswell, Milton, Johns Creek, Marietta, Canton, Acworth, Smyrna, Peachtree City, Newnan, McDonough, Conyers, Flowery Branch, Jefferson, Gainesville, Buford, Winder, Woodstock, Chateau Elan, Cumming, Dawson', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:51.418287'}
# peachtreebooks.com {'status': 'success', 'analysis': {'keywords': ['books', "children's books", "illustrated children's books", 'author', 'illustrator'], 'business_name': 'Peachtree Publishing Company Inc.', 'products_services': 'Children’s books, illustrated children’s books, authors, illustrators', 'emails': ['hello@peachtree-online.com'], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:52.686460'}
# peachtreeboutiquestore.com {'status': 'success', 'analysis': {'keywords': ['Peach Tree Boutique', 'Shopify', 'domain configuration'], 'business_name': 'Peach Tree Boutique', 'products_services': 'clothing, accessories, and home decor items', 'target_audience': 'female customers aged 25-45', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:53.664454'}
# peachtreechurch.com {'status': 'success', 'analysis': {'keywords': ['Peachtree Church', 'Christian church', 'Atlanta', 'Georgia', 'church website', 'religious organization'], 'business_name': 'Peachtree Church', 'products_services': "worship services, Sunday worship, children's worship, adult music, student music, weddings, messages, pastoral care, mentoring, serve, seed of hope, wonderfully made, hospitality, mission trips, giving, generosity 2025, ways to give, Peachtree Trust annual report", 'target_audience': 'local community, Atlanta, Georgia, United States, global audience', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:15:55.846785'}
# peachtreecitybraces.com {'status': 'success', 'analysis': {'keywords': ['orthodontic treatment', 'Peachtree City', 'Dr. Michael Mahaffey', 'Dr. Eric Linkous', 'friendly staff', 'accommodating', 'metal braces', 'clear aligners', 'clear braces'], 'business_name': 'Mahaffey Linkous Orthodontics', 'products_services': 'orthodontic treatment for all ages, metal braces, clear aligners, clear braces', 'target_audience': 'Peachtree City and surrounding areas residents looking for orthodontic treatment', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:57.851475'}
# peachtreecitydentalgroup.com {'status': 'success', 'analysis': {'keywords': ['family dentistry', 'general dentistry', 'cosmetic dentistry'], 'business_name': 'Peachtree City Dental Group', 'products_services': 'General dentistry, family dentistry, cosmetic dentistry', 'target_audience': 'Adults and children in Peachtree City and surrounding areas', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:15:58.840277'}
# peachtreecitymarket.com {'status': 'success', 'analysis': {'keywords': ['Peachtree City Market', 'local vendors', 'farmers market', 'healthy food', 'locally produced', 'gifts', 'bath & body products', 'pottery', 'jewelry', 'candles'], 'business_name': 'Peachtree City Market', 'products_services': 'food, produce, poultry, beef and pork, bread, sweet treats, honey, eggs, prepared foods, and so much more. Whether you’re looking to create a feast or simply don’t want to cook at all, we have you covered.', 'target_audience': 'foodies, local community, gift-givers', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:16:01.312575'}
# peachtreecitysmallenginerepair.com {'status': 'success', 'analysis': {'keywords': ['engine repair', 'small engine repair', 'Peachtree City'], 'business_name': 'Peachtree City Small Engine Repair', 'products_services': 'Small engine repair and maintenance services for lawn mowers, chain saws, generators, and other equipment.', 'target_audience': 'Residential and commercial customers in Peachtree City and surrounding areas.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:16:02.445858'}
# peachtreecitywokexpress.com {'status': 'success', 'analysis': {'keywords': ['Wok Express Chinese Restaurant', 'Chinese food', 'Peachtree City', 'restaurant', 'order online', 'delivery', 'pickup'], 'business_name': 'Wok Express Chinese Restaurant', 'products_services': 'Chinese food, dine-in, takeout, delivery', 'target_audience': 'Peachtree City residents and visitors', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:16:03.953189'}
# peachtreeclub.com {'status': 'success', 'analysis': {'keywords': ['Peachtree Club', 'City Club', 'Midtown Atlanta', 'elite business professionals', 'private dining club'], 'business_name': 'The Peachtree Club', 'products_services': 'high quality cuisine, elegant meeting space, and a multitude of social events including cocktail receptions, holidays parties, weddings and rehearsal dinners', 'target_audience': "Midtown's business Elite", 'emails': ['frontdesk@peachtreeclub.com', '817-0999frontdesk@peachtreeclub.com'], 'phones': ['']}, 'timestamp': '2024-12-24T16:16:05.749865'}
# peachtreecomedyfestival.com {'status': 'success', 'analysis': {'keywords': ['comedy festival', 'Peachtree Comedy', 'Big Mo Dixon'], 'business_name': 'Peachtree Comedy, LLC', 'products_services': 'Comedy festival and events', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:16:06.538349'}
# peachtreecornersexecutivesuites.com {'status': 'success', 'analysis': {'keywords': ['virtual office', 'executive suites', 'office space', 'meeting rooms', 'conference spaces', 'mail services', 'corporate mailing address'], 'business_name': 'Peachtree Corners Executive Suites', 'products_services': 'Virtual Office Address and Temporary Office/Meeting Space when needed, Accounts Month $50, When Combined with Meeting or Office Space Needs Day $23.80, Office Space as low as $750 per month, The ability to make copies onsite is also available for an additional fee, Wide range of on-site services', 'emails': ['info@peachtreecornersexecutivesuites.com'], 'phones': []}, 'timestamp': '2024-12-24T16:16:08.748414'}
# peachtreecpr.com {'status': 'success', 'analysis': {'keywords': ['CPR certification', 'luxury CPR training', 'mobile training', 'group classes'], 'business_name': 'Peachtree CPR', 'products_services': 'Luxury CPR Certification Services, Mobile Training, Group Classes', 'emails': ['filler@godaddy.comBookingsMy', 'filler@godaddy.comAccountBookingsMy', 'Peachtreecpr@gmail.comHoursAppointment', 'filler@godaddy.com', 'Peachtreecpr@gmail.com'], 'phones': ['']}, 'timestamp': '2024-12-24T16:16:09.874390'}
# peachtreecre.com {'status': 'success', 'analysis': {'keywords': ['peach treecre', 'security access denied', 'godaddy website firewall', 'whitelist IP'], 'business_name': 'Peach Treecre', 'products_services': 'Security solutions for websites', 'target_audience': 'Website owners and administrators', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:16:10.908477'}
# peachtreecrossings.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:16:10.908537'}
# peachtreedermatology.com {'status': 'success', 'analysis': {'keywords': ['cosmetic dermatology', 'skin cancer surgery', 'medical dermatology'], 'business_name': 'Peachtree Dermatology', 'products_services': 'CoolSculpting, laser hair removal, chemical peels, microdermabrasion, Botox, Juvederm, fillers, skin cancer surgery', 'target_audience': 'adults of all ages (18+)', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:16:12.616414'}
# peachtreedesigns.com {'status': 'success', 'analysis': {'keywords': ['furniture', 'artwork', 'lighting', 'mirrors', 'accessories', 'gifts'], 'business_name': 'Peach Tree Designs', 'products_services': 'a treasure trove of a home store', 'emails': ['info@peachtreedesigns.com'], 'phones': ['']}, 'timestamp': '2024-12-24T16:16:13.760731'}
# peachtreeestatescatawba.com {'status': 'success', 'analysis': {'keywords': ['luxury living', 'private oasis', 'gated community', 'Catawba Island', "Kelly's Island", 'Put-in-Bay', 'Cedar Point', 'custom-built homes', 'big-city adventures'], 'business_name': 'Peach Tree Estates Catawba', 'products_services': "luxury home lots and custom-built homes in a gated community on Catawba Island, with proximity to Ohio's top destinations and natural beauty", 'target_audience': 'individuals seeking luxurious living in a private oasis, including those looking for big-city adventures', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:16:16.014898'}
# peachtreeflowers.com {'status': 'success', 'analysis': {'keywords': ['flowers', 'plants', 'gardening', 'florist'], 'business_name': 'Peachtree Flowers', 'products_services': 'Fresh cut flowers, plants, and gardening supplies. Local florist delivering to Atlanta, GA and surrounding areas.', 'target_audience': 'Individuals and businesses in the Atlanta, GA area looking for fresh cut flowers, plants, and gardening supplies.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:16:17.228223'}
# peachtreegym.com {'status': 'success', 'analysis': {'keywords': ['gym', 'fitness', 'sports', 'dance', 'classes', 'facility', 'personal training', 'schedule', 'childcare', 'basketball', 'flag football', 'cheerleading', 'gymnastics', 'tumbling', 'private coaching'], 'business_name': 'The Gym at Peachtree', 'products_services': 'fitness classes, sports leagues, dance programs, personal training, facility rentals', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:16:19.113915'}
# peachtreegymnastics.com {'status': 'skipped', 'error': 'No valid content to analyze', 'timestamp': '2024-12-24T16:16:19.113973'}
# peachtreehearing.com {'status': 'success', 'analysis': {'keywords': ['hearing loss', 'tinnitus treatment', 'musician services', 'earwax removal'], 'business_name': 'Peachtree Hearing', 'products_services': 'hearing testing, hearing aid fitting, balance evaluation, musician & custom fit services, tinnitus treatment, earwax removal', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:16:20.481493'}
# peachtreehoops.com {'status': 'success', 'analysis': {'keywords': ['Atlanta Hawks', 'NBA Draft', 'NBA Summer League', 'NBA Free Agency', 'Hawks salary cap info'], 'business_name': 'Peachtree Hoops', 'products_services': 'NBA news, analysis, and community', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:16:21.796476'}
# peachtreehotelgroup.com {'status': 'success', 'analysis': {'keywords': ['commercial real estate', 'hotel management', 'credit/lending', 'acquisitions', 'development', 'asset management', 'capital markets', 'EB-5', 'film financing'], 'business_name': 'Peachtree Group', 'products_services': 'Investment firm specializing in commercial real estate, hotel management, credit/lending, acquisitions, development, asset management, capital markets, and film financing.', 'target_audience': 'Institutional investors, developers, hotel owners/operators, and film industry professionals.', 'emails': ['Relations470-826-3212Emailinfo@peachtreegroup.com', '678-823-7683ctalbert@peachtreegroup.com', 'Emailinfo@peachtreegroup.com', '30326Phone404-497-4111Emailinfo@peachtreegroup.comGet', 'Relations470-826-3212Emailinfo@peachtreegroup.comConnect'], 'phones': ['']}, 'timestamp': '2024-12-24T16:16:23.888615'}
# peachtreeinvitational.com {'status': 'success', 'analysis': {'keywords': ["Peachtree Men's Invitational", "men's gymnastics", 'Atlanta School of Gymnastics', 'Gene Watson', 'Joe Strank', 'Nathan Simmons', 'Tom Cook', 'Watson-Raines Gymnastics Award'], 'business_name': "Peachtree Men's Invitational", 'products_services': "Men's gymnastics competition and scholarships", 'target_audience': 'Male, high school and elite competitive gymnasts, gymnastics coaches and communities in Georgia and beyond', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:16:25.964528'}
# peachtreekidney.com {'status': 'success', 'analysis': {'keywords': ['kidney', 'hypertension', 'diabetes', 'treatment'], 'business_name': 'Peachtree Kidney and Hypertension Specialist Group', 'products_services': 'comprehensive care and health services for a wide array of kidney and vascular issues', 'target_audience': 'underserved communities with medical education, care and supplies', 'emails': ['info@peachtreekidney.com'], 'phones': ['']}, 'timestamp': '2024-12-24T16:16:27.517621'}
# peachtreekidsnantucket.com {'status': 'success', 'analysis': {'keywords': ['Nantucket', 'baby gifts', 'clothing', 'outerwear'], 'business_name': 'Peachtree Kids', 'products_services': 'clothing, shoes, and accessories for infants and children up to size 12', 'emails': ['hello@peachtreekidsnantucket.com'], 'phones': []}, 'timestamp': '2024-12-24T16:16:28.801890'}
# peachtreelanehoa.com {'status': 'success', 'analysis': {'keywords': ['Peach Tree Lane HOA', 'community living', 'neighborhood services'], 'business_name': 'Peach Tree Lane Homeowners Association', 'products_services': 'maintenance, management, and security services for community living', 'target_audience': 'residents of Peach Tree Lane and surrounding areas', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:16:29.792112'}
# peachtreelifeinsurance.com {'status': 'success', 'analysis': {'keywords': ['life insurance', 'compare quotes', 'best rates', 'independent agency', 'top insurance companies'], 'business_name': 'Peachtree Life Insurance', 'products_services': 'Life insurance quotes and policies', 'target_audience': 'Individuals across the nation seeking the best life insurance rates', 'emails': [], 'phones': ['']}, 'timestamp': '2024-12-24T16:16:31.165828'}
# peachtreelighting.com {'status': 'success', 'analysis': {'keywords': ['commercial lighting', 'products sold', 'network of professional representatives'], 'business_name': 'Peachtree Lighting', 'products_services': 'Our products are sold to the commercial lighting market through a network of professional representatives.', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:16:32.236269'}
# peachtreemedicalcenter.com {'status': 'success', 'analysis': {'keywords': ['high quality care', 'Peachtree Medical Center', 'Jim Sams Clinical Excellence Award', 'quality diabetes care', 'same day visits', 'translation services', 'Medicare'], 'business_name': 'Peachtree Medical Center', 'products_services': 'high quality medical care, including diabetes care and translation services', 'target_audience': 'patients in need of high quality medical care', 'emails': [], 'phones': []}, 'timestamp': '2024-12-24T16:16:33.927366'}

# %%
import pandas as pd
pd.DataFrame(analysis_results).T.to_csv('analysis_results.csv')

# %%
# store status , keywords , etc in diffrece columms 
res=pd.DataFrame(analysis_results)
res
# Out:
#                                 http://Sanjosebengalcats.com  \
# status                                               success
# analysis   {'keywords': ['Bengal cats', 'San Jose Bengal ...
# timestamp                         2024-12-24T16:14:00.057634
# error                                                    NaN
#
#                                         peachmarketplace.com  \
# status                                               success
# analysis   {'keywords': ['leopard', 'pumpkin', ' Hallowee...
# timestamp                         2024-12-24T16:14:01.612604
# error                                                    NaN
#
#                                            peachmcintyre.com  \
# status                                               success
# analysis   {'keywords': ['social media content creator', ...
# timestamp                         2024-12-24T16:14:03.021023
# error                                                    NaN
#
#                                             peachmedical.com  \
# status                                               success
# analysis   {'keywords': ['Pfizer', 'COVID-19', 'flu', 'ho...
# timestamp                         2024-12-24T16:14:04.486476
# error                                                    NaN
#
#                                          peachmeleggings.com  \
# status                                               success
# analysis   {'keywords': ['peachmeleggings', 'leggings', '...
# timestamp                         2024-12-24T16:14:06.078729
# error                                                    NaN
#
#                                                peachmode.com  \
# status                                               success
# analysis   {'keywords': ['sarees', 'fabric', 'cotton', 's...
# timestamp                         2024-12-24T16:14:08.237915
# error                                                    NaN
#
#                                              peachmodern.com  \
# status                                               success
# analysis   {'keywords': ['furniture', 'art', 'collectible...
# timestamp                         2024-12-24T16:14:09.341041
# error                                                    NaN
#
#                                               peach-momo.com  \
# status                                               success
# analysis   {'articles': [{'title': 'Best Now', 'descripti...
# timestamp                         2024-12-24T16:14:33.396954
# error                                                    NaN
#
#                                            peachmountain.com  \
# status                                               success
# analysis   {'keywords': ['tanks', 'fortifications', 'ship...
# timestamp                         2024-12-24T16:14:34.800705
# error                                                    NaN
#
#                         peachmusic.com  ...  \
# status                         skipped  ...
# analysis                           NaN  ...
# timestamp   2024-12-24T16:14:34.800766  ...
# error      No valid content to analyze  ...
#
#                                         peachtreehearing.com  \
# status                                               success
# analysis   {'keywords': ['hearing loss', 'tinnitus treatm...
# timestamp                         2024-12-24T16:16:20.481493
# error                                                    NaN
#
#                                           peachtreehoops.com  \
# status                                               success
# analysis   {'keywords': ['Atlanta Hawks', 'NBA Draft', 'N...
# timestamp                         2024-12-24T16:16:21.796476
# error                                                    NaN
#
#                                      peachtreehotelgroup.com  \
# status                                               success
# analysis   {'keywords': ['commercial real estate', 'hotel...
# timestamp                         2024-12-24T16:16:23.888615
# error                                                    NaN
#
#                                    peachtreeinvitational.com  \
# status                                               success
# analysis   {'keywords': ['Peachtree Men's Invitational', ...
# timestamp                         2024-12-24T16:16:25.964528
# error                                                    NaN
#
#                                          peachtreekidney.com  \
# status                                               success
# analysis   {'keywords': ['kidney', 'hypertension', 'diabe...
# timestamp                         2024-12-24T16:16:27.517621
# error                                                    NaN
#
#                                   peachtreekidsnantucket.com  \
# status                                               success
# analysis   {'keywords': ['Nantucket', 'baby gifts', 'clot...
# timestamp                         2024-12-24T16:16:28.801890
# error                                                    NaN
#
#                                         peachtreelanehoa.com  \
# status                                               success
# analysis   {'keywords': ['Peach Tree Lane HOA', 'communit...
# timestamp                         2024-12-24T16:16:29.792112
# error                                                    NaN
#
#                                   peachtreelifeinsurance.com  \
# status                                               success
# analysis   {'keywords': ['life insurance', 'compare quote...
# timestamp                         2024-12-24T16:16:31.165828
# error                                                    NaN
#
#                                        peachtreelighting.com  \
# status                                               success
# analysis   {'keywords': ['commercial lighting', 'products...
# timestamp                         2024-12-24T16:16:32.236269
# error                                                    NaN
#
#                                   peachtreemedicalcenter.com
# status                                               success
# analysis   {'keywords': ['high quality care', 'Peachtree ...
# timestamp                         2024-12-24T16:16:33.927366
# error                                                    NaN
#
# [4 rows x 97 columns]

# %%
data = []
for url, result in analysis_results.items():
    row = {
        'url': url,
        'status': result['status'],
        'timestamp': result.get('timestamp', '')
    }
    
    # Add analysis data if successful
    if result['status'] == 'success':
        analysis = result['analysis']
        row.update({
            'business_name': analysis.get('business_name', ''),
            'products_services': analysis.get('products_services', ''),
            'target_audience': analysis.get('target_audience', ''),
            'keywords': '|'.join(analysis.get('keywords', [])),
            'emails': '|'.join(analysis.get('emails', [])),
            'phones': '|'.join(analysis.get('phones', []))
        })
    else:
        row.update({
            'error': result.get('error', ''),
            'business_name': '',
            'products_services': '',
            'target_audience': '',
            'keywords': '',
            'emails': '',
            'phones': ''
        })
    
    data.append(row)

# Convert to DataFrame and save to CSV
df = pd.DataFrame(data)

# %%
df.to_csv('output/analysis_results_new.csv', index=False)

# %%
df
# Out:
#                              url   status                   timestamp  \
# 0   http://Sanjosebengalcats.com  success  2024-12-24T16:14:00.057634
# 1           peachmarketplace.com  success  2024-12-24T16:14:01.612604
# 2              peachmcintyre.com  success  2024-12-24T16:14:03.021023
# 3               peachmedical.com  success  2024-12-24T16:14:04.486476
# 4            peachmeleggings.com  success  2024-12-24T16:14:06.078729
# ..                           ...      ...                         ...
# 92    peachtreekidsnantucket.com  success  2024-12-24T16:16:28.801890
# 93          peachtreelanehoa.com  success  2024-12-24T16:16:29.792112
# 94    peachtreelifeinsurance.com  success  2024-12-24T16:16:31.165828
# 95         peachtreelighting.com  success  2024-12-24T16:16:32.236269
# 96    peachtreemedicalcenter.com  success  2024-12-24T16:16:33.927366
#
#                              business_name  \
# 0                     San Jose Bengal Cats
# 1                        Peach Marketplace
# 2                      Peach McIntyre Inc.
# 3                            Peach Medical
# 4                        Peach Me Leggings
# ..                                     ...
# 92                          Peachtree Kids
# 93  Peach Tree Lane Homeowners Association
# 94                Peachtree Life Insurance
# 95                      Peachtree Lighting
# 96                Peachtree Medical Center
#
#                                     products_services  \
# 0   Bengal kittens and Bengal cats for sale, Benga...
# 1   Home accessories, holiday collection, embroide...
# 2   Social Media Content Creator, Home Shop E-Guid...
# 3   Providing industry-leading fulfillment technol...
# 4   Women's leggings, shorts, flare pants, and set...
# ..                                                ...
# 92  clothing, shoes, and accessories for infants a...
# 93  maintenance, management, and security services...
# 94                 Life insurance quotes and policies
# 95  Our products are sold to the commercial lighti...
# 96  high quality medical care, including diabetes ...
#
#                                       target_audience  \
# 0           New York, Los Angeles, Miami, and beyond!
# 1
# 2
# 3
# 4
# ..                                                ...
# 92
# 93  residents of Peach Tree Lane and surrounding a...
# 94  Individuals across the nation seeking the best...
# 95
# 96      patients in need of high quality medical care
#
#                                              keywords  \
# 0   Bengal cats|San Jose Bengal Cats|Bengal kitten...
# 1   leopard|pumpkin| Halloween|embroidery|accessor...
# 2   social media content creator|big bag big bank|...
# 3            Pfizer|COVID-19|flu|home test|rapid test
# 4    peachmeleggings|leggings|shorts|flare pants|sets
# ..                                                ...
# 92            Nantucket|baby gifts|clothing|outerwear
# 93  Peach Tree Lane HOA|community living|neighborh...
# 94  life insurance|compare quotes|best rates|indep...
# 95  commercial lighting|products sold|network of p...
# 96  high quality care|Peachtree Medical Center|Jim...
#
#                                                emails phones error
# 0                          rene@sanjosebengalcats.com          NaN
# 1                                                              NaN
# 2   Inc.813.797.1396support@peachmcintyre.com|supp...          NaN
# 3                                                              NaN
# 4                                                              NaN
# ..                                                ...    ...   ...
# 92                   hello@peachtreekidsnantucket.com          NaN
# 93                                                             NaN
# 94                                                             NaN
# 95                                                             NaN
# 96                                                             NaN
#
# [97 rows x 10 columns]
